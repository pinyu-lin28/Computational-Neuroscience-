# %% [markdown]
# ## Question 1
# Please describe the most sophisticate computer programs that you have written so far.

# %% [markdown]
# * Most of my work has been using existing packages or modifying code available online. The one that I have written mostly by myself is a project using several machine learning modules (import from scikit-learning) to predict the survival months of breast cancer patients, which applied dimensionality reduction, data scaling, data balancing and hyperparameter adjustment for data preprocessing.

# %% [markdown]
# ## Question 2
# Please list the programming languages that you have any experience in.

# %% [markdown]
# * Python: Have written two projects using python to process medical images, which apply several machine learning models (using the existing machine learning modules available online and adjust the parameters and preprocess the images/datas).
#
# * Matlab: Familiar with basic MATLAB syntax, previously used it to read pre-processed MRI files and perform data analysis. However, I often need to consult the official MATLAB documentation to recall the detailed usage of many functions.
#
# * C++ : Only have done some simple homework two years ago (such as Ｍouse in a maze, Fibonacci Sequence)

# %% [markdown]
# ## Question 3
# What computer system do you have for school work?

# %% [markdown]
# * Type : Laptop
# * OS : Mac OS (macbook air with M4)
# * 10-Core CPU 8-Core GPU
# * 16GB Unified Memory
# * 256GB SSD Storage  footnote

# %% [markdown]
# ## Exercise 4

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt('/Users/pinyu/Documents/HW for 神經科學/hw1/hw01-dat.txt')

# %%
Time, x, y = data.T

# %%
plt.rcParams["font.family"] = "serif"
plt.rcParams["mathtext.fontset"] = "stix"

# %%
plt.figure()
plt.plot(Time, x)
plt.xlabel('$Time$ axis')
plt.ylabel('$x$ axis')
plt.show()

# %%
plt.figure()
plt.plot(Time, y)
plt.xlabel('$Time$ axis')
plt.ylabel('$y$ axis')
plt.show()

# %%
plt.figure()
plt.plot(x, y)
plt.axis('equal')
plt.xlabel('$x$ axis')
plt.ylabel('$y$ axis')
plt.show()
